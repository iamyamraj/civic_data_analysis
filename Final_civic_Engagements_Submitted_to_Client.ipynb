# %%
import geopandas as gpd

from ipyleaflet import Map, GeoData

from ipywidgets import HTML, Layout
from ipyleaflet import WidgetControl, LocalTileLayer

import pandas as pd

import plotly.express as px
import ipywidgets as widgets

Boundaries = ""
Year=""

def image_crop(Boundaries):
    defaultLayout = Layout(width='1260px', height='570px')

    # Paths to all files here!!!
    # Shapefiles
    municipal2008 = "ShapeFiles/Municipal/municipal2008.zip"
    municipal2011 = "ShapeFiles/Municipal/municipal2011.zip"
    fed2015 = "ShapeFiles/Federal/fed2015.zip"
    fed2019 = "ShapeFiles/Federal/fed2019.zip"
    fed2021 = "ShapeFiles/Federal/fed2021.zip"
    pro2013 = "ShapeFiles/Provincial/pro2013.zip"
    pro2017 = "ShapeFiles/Provincial/pro2017.zip"

    # Datafiles
    municipal_2008 = "DataFiles/Municipal/Municipal-2008.xlsx"
    municipal_2011 = "DataFiles/Municipal/Municipal-2011.xlsx"
    federal_2015 = "DataFiles/Federal/Federal_Data_2015.xlsx"
    federal_2019 = "DataFiles/Federal/Federal_Data_2019.xlsx"
    federal_2021 = "DataFiles/Federal/Federal_Data_2021.xlsx"
    provincial_2013 = ""
    provincial_2017 = "DataFiles/Provincial/Provincial_2017.xlsx"


    # Find Everything down Below!!!
    def plot():

        def Bound(Year,Heat_map=False,Satellite_view=False):
            #   Municipal Code down Here!!!
            def mun_2011():
                df = gpd.read_file(municipal2011)

                ex = pd.read_excel(municipal_2011)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                    Division No.:
                    {}

                    | Name:
                    {}

                    | Percentage :
                    {}

                    """.format(
                        feature["properties"]["division"],
                        feature["properties"]["name"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def mun_sat_2011():

                df = gpd.read_file(municipal2011)

                ex = pd.read_excel(municipal_2011)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                    Division No.:
                                    {}

                                    | Name:
                                    {}

                                    | Percentage :
                                    {}

                                    """.format(
                        feature["properties"]["division"],
                        feature["properties"]["name"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def mun_heat_2011():

                df = gpd.read_file(municipal2011)

                ex = pd.read_excel(municipal_2011)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")


                fig = px.choropleth(mi, geojson=geo_data, locations='division', color='color schema',
                                    color_continuous_scale="YLOrRd",
                                    range_color=(0, 6),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig

            def mun_2008():
                df = gpd.read_file(municipal2008)

                ex = pd.read_excel(municipal_2008)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                    Division No.:
                    {}

                    | Registered Votes:
                    {}

                    | Percentage :
                    {}

                    """.format(
                        feature["properties"]["division"],
                        feature["properties"]["regestered_votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def mun_sat_2008():

                df = gpd.read_file(municipal2008)

                ex = pd.read_excel(municipal_2008)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                    Division No.:
                                    {}

                                    | Registered Votes:
                                    {}

                                    | Percentage :
                                    {}

                                    """.format(
                        feature["properties"]["division"],
                        feature["properties"]["regestered_votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def mun_heat_2008():

                df = gpd.read_file(municipal2008)

                ex = pd.read_excel(municipal_2008)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")


                fig = px.choropleth(mi, geojson=geo_data, locations='division', color='colour schema',
                                    color_continuous_scale="Viridis",
                                    range_color=(0, 6),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig


            # Federal Code down here!!!!

            def fed_2015():
                df = gpd.read_file(fed2015)

                ex = pd.read_excel(federal_2015)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                               Division No.:
                               {}

                               | Total Votes:
                               {}

                               | Percentage :
                               {}

                               """.format(
                        feature["properties"]["PD_NUM"],
                        feature["properties"]["total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_sat_2015():

                df = gpd.read_file(fed2015)

                ex = pd.read_excel(federal_2015)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(
                    path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                               Division No.:
                                               {}

                                               | Total Votes:
                                               {}

                                               | Percentage :
                                               {}

                                               """.format(
                        feature["properties"]["PD_NUM"],
                        feature["properties"]["total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_heat_2015():

                df = gpd.read_file(fed2015)

                ex = pd.read_excel(federal_2015)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                fig = px.choropleth(mi, geojson=geo_data, locations='PD_NUM', color='Color Schema',
                                    color_continuous_scale="Viridis",
                                    range_color=(0, 12),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig

            def fed_2019():
                df = gpd.read_file(fed2019)

                ex = pd.read_excel(federal_2019)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                               Division No.:
                               {}

                               | Total Votes:
                               {}

                               | Percentage :
                               {}

                               """.format(
                        feature["properties"]["PDNUM"],
                        feature["properties"]["Total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_sat_2019():

                df = gpd.read_file(fed2019)

                ex = pd.read_excel(federal_2019)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(
                    path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                               Division No.:
                                               {}

                                               | Total votes:
                                               {}

                                               | Percentage :
                                               {}

                                               """.format(
                        feature["properties"]["PDNUM"],
                        feature["properties"]["Total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_heat_2019():

                df = gpd.read_file(fed2019)

                ex = pd.read_excel(federal_2019)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                fig = px.choropleth(mi, geojson=geo_data, locations='PDNUM', color='Color Schema',
                                    color_continuous_scale="Viridis",
                                    range_color=(0, 12),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig

            def fed_2021():
                df = gpd.read_file(fed2021)

                ex = pd.read_excel(federal_2021)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                               Division No.:
                               {}

                               | Total votes:
                               {}

                               | Percentage :
                               {}

                               """.format(
                        feature["properties"]["PD_NUM"],
                        feature["properties"]["Total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_sat_2021():

                df = gpd.read_file(fed2021)

                ex = pd.read_excel(federal_2021)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(
                    path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                               Division No.:
                                               {}

                                               | Total votes:
                                               {}

                                               | Percentage :
                                               {}

                                               """.format(
                        feature["properties"]["PD_NUM"],
                        feature["properties"]["Total votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def fed_heat_2021():

                df = gpd.read_file(fed2021)

                ex = pd.read_excel(federal_2021)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                fig = px.choropleth(mi, geojson=geo_data, locations='PD_NUM', color='Color Schema',
                                    color_continuous_scale="Viridis",
                                    range_color=(0, 12),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig

            #Provincial Code down here!!!!!


            def pro_2017():
                df = gpd.read_file(pro2017)

                ex = pd.read_excel(provincial_2017)

                df["VA_CODE"] = df["VA_CODE"].astype(int)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)
                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                    Sub-Division No.:
                    {}

                    | Registered Votes:
                    {}

                    | Percentage :
                    {}

                    """.format(
                        feature["properties"]["VA_CODE"],
                        feature["properties"]["registered_votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def pro_sat_2017():

                df = gpd.read_file(pro2017)

                ex = pd.read_excel(provincial_2017)

                df["VA_CODE"] = df["VA_CODE"].astype(int)

                mi = pd.merge(ex, df)

                map = Map(center=(49.26742200000007, -123.10661199999998), zoom=12, scroll_wheel_zoom=True)

                map.add_layer(LocalTileLayer(path="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}"))

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")

                map.add(geo_data)

                html = HTML("""Hover over a state""")
                html.layout.margin = "0px 20px 20px 20px"
                control = WidgetControl(widget=html, position="topright")
                map.add(control)

                def update_html(feature, **kwargs):
                    html.value = """

                                    Division No.:
                                    {}

                                    | Registered Votes:
                                    {}

                                    | Percentage :
                                    {}

                                    """.format(
                        feature["properties"]["VA_CODE"],
                        feature["properties"]["registered_votes"],
                        feature["properties"]["percentage"],
                    )

                geo_data.on_hover(update_html)
                return map

            def pro_heat_2017():

                df = gpd.read_file(pro2017)

                ex = pd.read_excel(provincial_2017)

                df["VA_CODE"] = df["VA_CODE"].astype(int)

                mi = pd.merge(ex, df)

                geo_ptal_lsoas = gpd.GeoDataFrame(mi, geometry='geometry')

                geo_data = GeoData(geo_dataframe=geo_ptal_lsoas,
                                   style={
                                       "color": "black",
                                       "fillColor": "#366370",
                                       "opacity": 0.05,
                                       "weight": 1.9,
                                       "dashArray": "2",
                                       "fillOpacity": 0.6,
                                   },
                                   hover_style={"fillColor": "#b08a3e", "fillOpacity": 0.9},
                                   geometry="geometry")


                fig = px.choropleth(mi, geojson=geo_data, locations='VA_CODE', color='color schema',
                                    color_continuous_scale="Viridis",
                                    range_color=(0, 6),
                                    scope="north america",
                                    )
                fig.update_geos(fitbounds="locations", visible=False)

                return fig

            def pro():
                return ""







            # Only Municipal
            if Boundaries == "Municipal" and Year == 2011 and Satellite_view == True:
                return mun_sat_2011()
            elif Boundaries == "Municipal" and Year == 2011 and Heat_map==True:
                return mun_heat_2011()
            elif Boundaries == "Municipal" and Year == 2011:
                return mun_2011()
            elif Boundaries == "Municipal" and Year == 2008 and Satellite_view == True:
                return mun_sat_2008()
            elif Boundaries == "Municipal" and Year == 2008 and Heat_map==True:
                return mun_heat_2008()
            elif Boundaries == "Municipal" and Year == 2008:
                return mun_2008()
            # Provincial Changes in data and year
            elif Boundaries == "Provincial" and Year == 2013 and Satellite_view == True:
                return pro()
            elif Boundaries == "Provincial" and Year == 2013 and Heat_map==True:
                return pro()
            elif Boundaries == "Provincial" and Year == 2013:
                return pro()
            elif Boundaries == "Provincial" and Year == 2017 and Satellite_view == True:
                return pro_sat_2017()
            elif Boundaries == "Provincial" and Year == 2017 and Heat_map==True:
                return pro_heat_2017()
            elif Boundaries == "Provincial" and Year == 2017:
                return pro_2017()
            #Federal Changes in data and year
            elif Boundaries == "Federal" and Year == 2015 and Satellite_view == True:
                return fed_sat_2015()
            elif Boundaries == "Federal" and Year == 2015 and Heat_map==True:
                return fed_heat_2015()
            elif Boundaries == "Federal" and Year == 2015:
                return fed_2015()
            elif Boundaries == "Federal" and Year == 2019 and Satellite_view == True:
                return fed_sat_2019()
            elif Boundaries == "Federal" and Year == 2019 and Heat_map==True:
                return fed_heat_2019()
            elif Boundaries == "Federal" and Year == 2019:
                return fed_2019()
            elif Boundaries == "Federal" and Year == 2021 and Satellite_view == True:
                return fed_sat_2021()
            elif Boundaries == "Federal" and Year == 2021 and Heat_map==True:
                return fed_heat_2021()
            elif Boundaries == "Federal" and Year == 2021:
                return fed_2021()






        if Boundaries == "Municipal":
            return widgets.interact(Bound, Year=[2008, 2011],Heat_map=False,Satellite_view=False)
        elif Boundaries == "Federal":
            return widgets.interact(Bound, Year=[2015,2019,2021])
        elif Boundaries == "Provincial":
            return widgets.interact(Bound, Year=[2013,2017])



        return Bound(Year)
    return plot()


widgets.interact(image_crop, Boundaries=["Federal","Municipal","Provincial"])
# Out:
# interactive(children=(Dropdown(description='Boundaries', options=('Federal', 'Municipal', 'Provincial'), value…
# <function __main__.image_crop(Boundaries)>
